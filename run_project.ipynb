# %% [markdown]
# ## Load model

# %%
# Load model
import os
from cobra.io import read_sbml_model, write_sbml_model
from cobra.util import create_stoichiometric_matrix
import numpy as np
from cobra import Reaction, Metabolite

script_path = os.getcwd()
path_sbml3fbc = 'iCre1355_auto_fbc.xml'

model = read_sbml_model(os.path.join(script_path, path_sbml3fbc))  # magic, no warnings
# Out:
# No objective coefficients in model. Unclear what should be optimized

# %%
model
# Out:
# <Model iCre1355 at 0x15db4ef50>

# %% [markdown]
# ## Memote assessment

# %%
print("The model has %d reactions, %d metabolites and %d genes" % (len(model.reactions), len(model.metabolites), len(model.genes)))
# Out:
# The model has 2394 reactions, 1845 metabolites and 1963 genes

# %%
S = create_stoichiometric_matrix(model)
# Check non-zero elements of S
non_zero_elem = np.count_nonzero(S)
zero_elem = np.count_nonzero(S==0)
print("The percentage of non-zero elements in S is:", str(non_zero_elem/(zero_elem + non_zero_elem)*100) + "%")
# Out:
# The percentage of non-zero elements in S is: 0.2494492781185122%

# %%
print('Available growth conditions:')
for reaction in model.reactions.query('Biomass', 'name'):
    model.objective = reaction.id
    print(reaction.id)

print('')
print('Base medium')
medium = model.medium
for mol in medium.keys():
    print(f'{mol} = {medium[mol]}')
    
print('')
print('growth rate in different conditions in standard medium:')
for reaction in model.reactions.query('Biomass', 'name'):
    model.objective = reaction.id
    solution = model.optimize()
    growth_rate = solution.objective_value
    print(f"condition: {reaction.id}   \t growth_rate: {growth_rate}")
# Out:
# Available growth conditions:
# Biomass_Chlamy_auto
# Biomass_Chlamy_mixo
# Biomass_Chlamy_hetero
#
# Base medium
# EX_h_e = 10.0
# EX_h2o_e = 10.0
# EX_pi_e = 10.0
# EX_nh4_e = 1.0
# EX_so4_e = 10.0
# EX_fe2_e = 10.0
# EX_mg2_e = 10.0
# EX_na1_e = 10.0
# EX_photonVis_e = 80.0
# EX_o2_e = 10.0
# EX_co2_e = 2.0
# EX_ac_e = 17.5
#
# growth rate in different conditions in standard medium:
# condition: Biomass_Chlamy_auto   	 growth_rate: 0.14866600668259908
# condition: Biomass_Chlamy_mixo   	 growth_rate: 0.0
# condition: Biomass_Chlamy_hetero   	 growth_rate: 0.0

# %% [markdown]
# ## Change medium

# %%
# Change medium composition (add 17.5 mM of acetate, remove photons)
changes = {'EX_ac_e' : 17.5, # add acetate
           'EX_photonVis_e' : 80. # remove photons
          }

medium = model.medium
for mol in changes.keys():
    val = changes[mol]
    medium[mol] = val

model.medium = medium
model.medium

print('')
print('growth rate in different conditions in standard medium:')
for reaction in model.reactions.query('Biomass', 'name'):
    model.objective = reaction.id
    solution = model.optimize()
    growth_rate = solution.objective_value
    print(f"condition: {reaction.id}   \t growth_rate: {growth_rate}")
# Out:
# growth rate in different conditions in standard medium:
# condition: Biomass_Chlamy_auto   	 growth_rate: 0.14866600668259908
# condition: Biomass_Chlamy_mixo   	 growth_rate: 0.0
# condition: Biomass_Chlamy_hetero   	 growth_rate: 0.0

# %% [markdown]
# ## can it grow on glucose?

# %%
for x in model.reactions:
    if 'EX_ac_e' in x.id or 'ac_e' in x.reaction:
        print("%s : %s" % (x.id, x.reaction))

model.reactions.get_by_id('ACt')
# Out:
# EX_ac_e : ac_e <=>
# ACt : ac_e <=> ac_c
# <Reaction ACt at 0x1673f3490>

# %%
biomass_rxn = model.reactions.get_by_id("Biomass_Chlamy_auto")
biomass_rxn
# Out:
# <Reaction Biomass_Chlamy_auto at 0x167613390>

# %%
model.reactions.get_by_id("Biomass_Chlamy_auto")
# Out:
# <Reaction Biomass_Chlamy_auto at 0x167613390>

# %%
model.demands
# Out:
# [<Reaction DM_apotfen_h at 0x15e20ee10>,
#  <Reaction DM_asnglcnacglcnacman_LPAREN_man_RPAREN_man_c at 0x1626f7810>,
#  <Reaction DM_bhb_m at 0x162727550>,
#  <Reaction DM_bhb_x at 0x162727d10>,
#  <Reaction DM_cat_c at 0x16271d2d0>,
#  <Reaction DM_ficytb5_c at 0x162727fd0>,
#  <Reaction DM_glu5sa_m at 0x16272c310>,
#  <Reaction DM_hcarn_c at 0x16272c610>,
#  <Reaction DM_icit_h at 0x16272c910>,
#  <Reaction DM_na1_c at 0x16272cc10>,
#  <Reaction DM_na1_h at 0x16272cf10>,
#  <Reaction DM_na1_m at 0x16272d250>,
#  <Reaction DM_na1_x at 0x16272d590>,
#  <Reaction DM_no_h at 0x16272d8d0>,
#  <Reaction DM_o2D_u at 0x16272dc10>,
#  <Reaction DM_photon298_c at 0x16272e650>,
#  <Reaction DM_photon437_u at 0x16272e950>,
#  <Reaction DM_photon438_u at 0x16272ec90>,
#  <Reaction DM_photon450_h at 0x16272efd0>,
#  <Reaction DM_photon490_s at 0x16272f310>,
#  <Reaction DM_photon646_h at 0x16272f650>,
#  <Reaction DM_photon673_u at 0x16272f990>,
#  <Reaction DM_photon680_u at 0x16272fcd0>,
#  <Reaction DM_udg_m at 0x16272f910>,
#  <Reaction DM_urdglyc_m at 0x16272fc50>,
#  <Reaction DM_pqa_h at 0x16272ff90>,
#  <Reaction DM_amob_m at 0x162734350>,
#  <Reaction DM_12dgr18111Z160_c at 0x162734690>,
#  <Reaction DM_12dgr1819Z160_c at 0x162734990>,
#  <Reaction DM_dad_5_c at 0x162734c90>,
#  <Reaction DM_callose_c at 0x162734f50>,
#  <Reaction DM_callose_f at 0x162735290>,
#  <Reaction DM_pcb_c at 0x1627355d0>,
#  <Reaction DM_fe2_h at 0x162735910>,
#  <Reaction DM_starch_h at 0x162735c50>,
#  <Reaction DM_tag_c at 0x162735f90>]

# %% [markdown]
# ## Add heterologous mets and rxns

# %%
# Add heterologous metabolites and reactions
### Create metabolite ###
metabolite1 = Metabolite('jet_juice_c')
metabolite1.name = 'Jet Juice'
metabolite1.formula = 'C29H38O2'
metabolite1.compartment = 'c'
model.add_metabolites([metabolite1])

### Define production of jet fuel reaction ###
reaction1 = Reaction('jet_fuel')
reaction1.name = 'iPKS'
reaction1.lower_bound = 0.  # This makes the reaction irreversible
reaction1.upper_bound = 1000.  # This is the default ub

# Add metabolites to the reaction
reaction1.add_metabolites({
    model.metabolites.get_by_id("ac_c"): -11.0,
    model.metabolites.get_by_id("nadp_c"): 11.0,
    model.metabolites.get_by_id("amet_c"): -7.0,
    model.metabolites.get_by_id("ahcys_c"): 7.0,
    model.metabolites.get_by_id("nadph_c"): -11.0,
    model.metabolites.get_by_id("h_c"): 11.0,
    model.metabolites.get_by_id("jet_juice_c"): 1.0
})

### Define jet fuel exchange reaction ###
reaction2 = Reaction('EX_jet_fuel')
reaction2.name = 'Jet Fuel exchange'
reaction2.lower_bound = 0.  # This makes the reaction irreversible
reaction2.upper_bound = 1000.  # This is the default ub

# Add metabolites to the reaction
reaction2.add_metabolites({
    model.metabolites.get_by_id("jet_juice_c"): -1.0
})

model.add_reactions([reaction1, reaction2])

print(reaction1.reaction)
print(reaction2.reaction)
# Out:
# 11.0 ac_c + 7.0 amet_c + 11.0 nadph_c --> 7.0 ahcys_c + 11.0 h_c + jet_juice_c + 11.0 nadp_c
# jet_juice_c -->

# %% [markdown]
# ## Set model objective and get max theoretical yield

# %%
# Add objective function
model.objective = 'jet_fuel'

# %%
# Simulate the model and get max theoretical yield of jet fuel

solution = model.optimize()
solution
# Out:
# <Solution 0.782 at 0x17f668610>

# %%
# Check what is the minimal medium to grow C.reinhardtii with acetate

from cobra.medium import minimal_medium

max_fuel = model.slim_optimize()
print("The maximum theoretical jet fuel yield we can produce in these conditions is", max_fuel)
minimal_medium(model, max_fuel)
# Out:
# The maximum theoretical jet fuel yield we can produce in these conditions is 0.7817186183656271
# /Users/jonathanfunk/miniforge3/envs/cell_factory/lib/python3.11/site-packages/cobra/medium/minimal_medium.py:112: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   medium = pd.Series()
# EX_na1_e     2.824684
# EX_o2_e      5.294693
# EX_ac_e     17.500000
# dtype: float64

# %%
# Get molar yield (mol jet fuel / mol acetate)

solution.fluxes['EX_jet_fuel'] / (-1. * solution.fluxes['EX_ac_e'])
# Out:
# 0.0429801474758934

# %% [markdown]
# ## Plot phenotypic phase planes

# %%
from cobra.flux_analysis.phenotype_phase_plane import production_envelope

# %%
ppp_ac = production_envelope(model,
                    reactions=[model.reactions.EX_ac_e],
                    objective=model.reactions.jet_fuel)

# %%
# Phenotypic phase plane (ppp) of acetate

ppp_ac
# Out:
#    carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0        EX_ac_e           0.0                   0.0                 NaN
# 1        EX_ac_e           0.0                   0.0                 NaN
# 2        EX_ac_e           0.0                   0.0                 NaN
# 3        EX_ac_e           0.0                   0.0                 NaN
# 4        EX_ac_e           0.0                   0.0                 NaN
# 5        EX_ac_e           0.0                   0.0                 NaN
# 6        EX_ac_e           0.0                   0.0                 NaN
# 7        EX_ac_e           0.0                   0.0                 NaN
# 8        EX_ac_e           0.0                   0.0                 NaN
# 9        EX_ac_e           0.0                   0.0                 NaN
# 10       EX_ac_e           0.0                   0.0                 NaN
# 11       EX_ac_e           0.0                   0.0                 NaN
# 12       EX_ac_e           0.0                   0.0                 NaN
# 13       EX_ac_e           0.0                   0.0                 NaN
# 14       EX_ac_e           0.0                   0.0                 NaN
# 15       EX_ac_e           0.0                   0.0                 NaN
# 16       EX_ac_e           0.0                   0.0                 NaN
# 17       EX_ac_e           0.0                   0.0                 NaN
# 18       EX_ac_e           0.0                   0.0                 NaN
# 19       EX_ac_e           0.0                   0.0                 NaN
#
#     flux_maximum  carbon_yield_maximum  mass_yield_maximum    EX_ac_e
# 0       0.781719          7.995865e+00                 NaN -17.500000
# 1       0.742547          7.988239e+00                 NaN -16.638947
# 2       0.703343          7.979418e+00                 NaN -15.777895
# 3       0.663999          7.967894e+00                 NaN -14.916842
# 4       0.624655          7.954957e+00                 NaN -14.055789
# 5       0.585311          7.940333e+00                 NaN -13.194737
# 6       0.545966          7.923666e+00                 NaN -12.333684
# 7       0.506622          7.904497e+00                 NaN -11.472632
# 8       0.467278          7.882218e+00                 NaN -10.611579
# 9       0.427552          7.848996e+00                 NaN  -9.750526
# 10      0.387814          7.809089e+00                 NaN  -8.889474
# 11      0.348076          7.760621e+00                 NaN  -8.028421
# 12      0.308337          7.700508e+00                 NaN  -7.167368
# 13      0.268599          7.623980e+00                 NaN  -6.306316
# 14      0.228861          7.523249e+00                 NaN  -5.445263
# 15      0.189122          7.384677e+00                 NaN  -4.584211
# 16      0.149384          7.182011e+00                 NaN  -3.723158
# 17      0.103741          6.488122e+00                 NaN  -2.862105
# 18      0.051871          4.639980e+00                 NaN  -2.001053
# 19      0.000000          1.267814e-13                 NaN  -1.140000

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline

ppp_ac.plot(x='EX_ac_e', y='flux_maximum');
# Out:
# /var/folders/sd/pr3fylj57wlgrmcxg1v4zp3c0000gn/T/ipykernel_51197/1752839450.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
# Phenotypic phase plane (ppp) of acetate (aerobic vs anaerobic)

ppp_ac_3D = production_envelope(model, reactions=[model.reactions.EX_ac_e, model.reactions.EX_o2_e],
                                   objective=model.reactions.jet_fuel, points=50)

# %%
import pandas
pandas.options.display.max_rows = 12
ppp_ac_3D
# Out:
#      carbon_source  flux_minimum  carbon_yield_minimum  mass_yield_minimum  \
# 0          EX_ac_e           0.0          0.000000e+00                 NaN
# 1          EX_ac_e           0.0          0.000000e+00                 NaN
# 2          EX_ac_e           0.0          0.000000e+00                 NaN
# 3          EX_ac_e           0.0          0.000000e+00                 NaN
# 4          EX_ac_e           0.0          0.000000e+00                 NaN
# ...            ...           ...                   ...                 ...
# 2495       EX_ac_e           0.0          1.064167e-15                 NaN
# 2496       EX_ac_e           NaN                   NaN                 NaN
# 2497       EX_ac_e           NaN                   NaN                 NaN
# 2498       EX_ac_e           NaN                   NaN                 NaN
# 2499       EX_ac_e           NaN                   NaN                 NaN
#
#       flux_maximum  carbon_yield_maximum  mass_yield_maximum  EX_ac_e  \
# 0         0.744235          7.612463e+00                 NaN   -17.50
# 1         0.746118          7.631717e+00                 NaN   -17.50
# 2         0.747889          7.649841e+00                 NaN   -17.50
# 3         0.749496          7.666275e+00                 NaN   -17.50
# 4         0.751103          7.682708e+00                 NaN   -17.50
# ...            ...                   ...                 ...      ...
# 2495      0.000000          5.388212e-14                 NaN    -1.14
# 2496           NaN                   NaN                 NaN    -1.14
# 2497           NaN                   NaN                 NaN    -1.14
# 2498           NaN                   NaN                 NaN    -1.14
# 2499           NaN                   NaN                 NaN    -1.14
#
#         EX_o2_e
# 0    -10.000000
# 1     -9.795918
# 2     -9.591837
# 3     -9.387755
# 4     -9.183673
# ...         ...
# 2495  -0.816327
# 2496  -0.612245
# 2497  -0.408163
# 2498  -0.204082
# 2499   0.000000
#
# [2500 rows x 9 columns]

# %%
ppp_ac_3D.plot(x='EX_o2_e', y='flux_maximum');

# Explanation: As the concentration of acetate decreases in the medium, the flux maximum (y axis)
# of jet fuel is reduced (as expected). There is something surprising in the graph, because
# when [Acetate] decreases, less oxygen allows to increase the flux_maximum until a certain point,
# where the oxygen levels are too low and the production of jet fuel decreases again.

# %%
ppp_ac_3D.plot();

# Explanation: WTF is this?

# %%
from cameo.flux_analysis import phenotypic_phase_plane
from cameo.visualization.plotting.with_plotly import PlotlyPlotter
plotter = PlotlyPlotter()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 from cameo.flux_analysis import phenotypic_phase_plane
#       2 from cameo.visualization.plotting.with_plotly import PlotlyPlotter
#       3 plotter = PlotlyPlotter()
#
# ModuleNotFoundError: No module named 'cameo'

# %%
ppp_ac_3D = phenotypic_phase_plane(model, variables=[model.reactions.EX_ac_e, model.reactions.EX_o2_e],
                                   objective=model.reactions.jet_fuel, points=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 ppp_ac_3D = phenotypic_phase_plane(model, variables=[model.reactions.EX_ac_e, model.reactions.EX_o2_e],
#       2                                    objective=model.reactions.jet_fuel, points=50)
#
# NameError: name 'phenotypic_phase_plane' is not defined

# %%
ppp_ac_3D.data_frame
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [28], line 1
# ----> 1 ppp_ac_3D.data_frame
#
# File ~/miniforge3/envs/cell_factory/lib/python3.11/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'data_frame'

# %%
import warnings
warnings.filterwarnings('ignore')
ppp_ac_3D.plot(plotter)

# %% [markdown]
# ## Compute Gene knockout strategies (not done due to Error)

# %%
# See what genes are essential in our model

import matplotlib.pyplot as plt
plt.style.use('ggplot')
from pandas import DataFrame
from cobra.io import read_sbml_model
# %matplotlib inline

# %%
essentiality = {}
for gene in model.genes:
    with model:
        gene.knock_out()
        essentiality[gene] = model.slim_optimize(error_value=0.)

# %%
essentiality[:10]

# %%
df = DataFrame.from_dict(essentiality, orient='index')
df = df.rename(columns={0: 'jet_fuel'})
df = df.sort_values('jet_fuel')

# %%
df.plot.hist()

# %%
ax = df.plot.bar().axes
ax.figure.set_size_inches(32, 18)

# %%
from cameo.strain_design.deterministic.linear_programming import OptKnock

# %% [markdown]
# ## Escher (unsuccessful attempt)

# %%
import escher

# %%
solution = model.optimize()

# %%
# !wget -nc http://bigg.ucsd.edu/static/models/iRC1080.json
# Out:
# File ‘iRC1080.json’ already there; not retrieving.

# %%
escher.Builder(map_json='iRC1080.json',
               reaction_data=solution.fluxes.to_dict(),model=model, highlight_missing=True).display_in_notebook()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In [54], line 2
#       1 escher.Builder(map_json='iRC1080.json',
# ----> 2                reaction_data=solution.fluxes.to_dict(),model=model, highlight_missing=True).display_in_notebook()
#
# File ~/miniforge3/envs/cell_factory/lib/python3.11/site-packages/escher/plots.py:583, in Builder.display_in_notebook(self, *args, **kwargs)
#     570 def display_in_notebook(self, *args, **kwargs):
#     571     """Deprecated.
#     572
#     573     The Builder is now a Jupyter Widget, so you can return the Builder
#    (...)
#     581
#     582     """
# --> 583     raise Exception(('display_in_notebook is deprecated. The Builder is '
#     584                      'now a Jupyter Widget, so you can return the '
#     585                      'Builder in a cell to see it, or use the IPython '
#     586                      'display function (see Escher docs for details)'))
#
# Exception: display_in_notebook is deprecated. The Builder is now a Jupyter Widget, so you can return the Builder in a cell to see it, or use the IPython display function (see Escher docs for details)

# %%
escher.list_available_maps()
# Out:
# [{'organism': 'Saccharomyces cerevisiae',
#   'map_name': 'iMM904.Central carbon metabolism'},
#  {'organism': 'Homo sapiens',
#   'map_name': 'RECON1.Inositol retinol metabolism'},
#  {'organism': 'Homo sapiens', 'map_name': 'RECON1.Glycolysis TCA PPP'},
#  {'organism': 'Homo sapiens', 'map_name': 'RECON1.Tryptophan metabolism'},
#  {'organism': 'Homo sapiens', 'map_name': 'RECON1.Carbohydrate metabolism'},
#  {'organism': 'Homo sapiens',
#   'map_name': 'RECON1.Amino acid metabolism (partial)'},
#  {'organism': 'Escherichia coli', 'map_name': 'iJO1366.Nucleotide metabolism'},
#  {'organism': 'Escherichia coli',
#   'map_name': 'iJO1366.Fatty acid biosynthesis (saturated)'},
#  {'organism': 'Escherichia coli',
#   'map_name': 'iJO1366.Nucleotide and histidine biosynthesis'},
#  {'organism': 'Escherichia coli', 'map_name': 'e_coli_core.Core metabolism'},
#  {'organism': 'Escherichia coli', 'map_name': 'iJO1366.Central metabolism'},
#  {'organism': 'Escherichia coli',
#   'map_name': 'iJO1366.Fatty acid beta-oxidation'}]

# %%
builder = escher.Builder

# !wget -nc http://bigg.ucsd.edu/static/models/iAB_RBC_283.json

builder = builder(
    model_json='iAB_RBC_283.json'
)

builder
# Out:
# File ‘iAB_RBC_283.json’ already there; not retrieving.
# Builder()

# %% [markdown]
# ## Simulate batch cultivations using dynamic FBA (failed due to Error)

# %%
from os.path import dirname, join, pardir
from cobra.io import read_sbml_model
from dfba import DfbaModel, ExchangeFlux, KineticVariable
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [57], line 3
#       1 from os.path import dirname, join, pardir
#       2 from cobra.io import read_sbml_model
# ----> 3 from dfba import DfbaModel, ExchangeFlux, KineticVariable
#
# ModuleNotFoundError: No module named 'dfba'

# %% [markdown]
# # QUESTIONS

# %% [markdown]
# 2. Calculate theoretical yields for other carbon sources?
# 3. Plot ppp for other conditions (e.g. anaerobic)?
# 4. Computationally enumerate all potential production pathways to your chosen product (even if it is a native product) and score them by different metrics (yield, number of steps added) - NOT APPLICABLE, right?
# 5. A \
# X. Assess again model w/ modifications using MEMOTE \
# X. Can't use escher with our organism I think...
